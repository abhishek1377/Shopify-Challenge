# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("2019 Winter Data Science Intern Challenge Data Set.xlsx")

# %%
df
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0            1       53      746           224            2           cash
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4995      4996       73      993           330            2          debit
# 4996      4997       48      789           234            2           cash
# 4997      4998       56      867           351            3           cash
# 4998      4999       60      825           354            2    credit_card
# 4999      5000       44      734           288            2          debit
#
#                   created_at
# 0    2017-03-13 12:36:56.190
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        5000 non-null   int64
#  1   shop_id         5000 non-null   int64
#  2   user_id         5000 non-null   int64
#  3   order_amount    5000 non-null   int64
#  4   total_items     5000 non-null   int64
#  5   payment_method  5000 non-null   object
#  6   created_at      5000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 273.6+ KB

# %%
for col in df:
    print(col,": ",len(df[col].unique()),"\n", df[col].unique())
# Out:
# order_id :  5000
#  [   1    2    3 ... 4998 4999 5000]
# shop_id :  100
#  [ 53  92  44  18  58  87  22  64  52  66  40  54 100  42  17  28  83  63
#   97  88  75  73  82  47  59  76  57   7  34  61  84  10   1  21  99  29
#   33   3  81  30  79  51  80  60  86  91  72  11  14   5  20  41   8  48
#   56  55  50  35  70  77  74  13  12  68  69  25   6  98  24   2  49  15
#   71  16   9  78  93  37  26  43  85  19  27  31  67  36  39  89  32  23
#   96  95  38  62   4  90  94  46  65  45]
# user_id :  301
#  [746 925 861 935 883 882 915 761 914 788 848 983 799 709 849 607 731 752
#  898 987 789 985 964 917 942 944 790 857 839 712 800 704 781 979 961 921
#  756 793 847 934 792 759 969 954 791 714 768 984 959 968 842 823 851 739
#  837 908 720 981 962 887 988 743 812 994 876 725 813 960 862 744 975 806
#  838 868 817 707 711 713 998 705 835 856 810 758 850 741 972 923 740 803
#  953 732 926 774 893 885 755 745 958 997 949 884 963 721 723 777 894 845
# ...

# %%
# df

# %% [markdown]
# looking at the timeframe

# %%
max(df["created_at"])
# Out:
# Timestamp('2017-03-30 23:55:35.408000')

# %%
min(df["created_at"])
# Out:
# Timestamp('2017-03-01 00:08:09.179000')

# %% [markdown]
# Its a one month period alright.

# %%
np.mean(df["order_amount"])
# Out:
# 3145.128

# %%
df_witout_outliers = df[df["order_amount"]< 500000]

# %%
df_witout_outliers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4983 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        4983 non-null   int64
#  1   shop_id         4983 non-null   int64
#  2   user_id         4983 non-null   int64
#  3   order_amount    4983 non-null   int64
#  4   total_items     4983 non-null   int64
#  5   payment_method  4983 non-null   object
#  6   created_at      4983 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 311.4+ KB

# %%
df_outliers = df[df["order_amount"]> 500000]

# %%
df_outliers["user_id"].unique()
# Out:
# array([607])

# %%
df["order_value_per_item"] = df["order_amount"]/df["total_items"]

# %%
df
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0            1       53      746           224            2           cash
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4995      4996       73      993           330            2          debit
# 4996      4997       48      789           234            2           cash
# 4997      4998       56      867           351            3           cash
# 4998      4999       60      825           354            2    credit_card
# 4999      5000       44      734           288            2          debit
#
#                   created_at  order_value_per_item
# ...

# %%
max(df["order_value_per_item"])
# Out:
# 25725.0

# %%
df[df["order_value_per_item"] > 1000]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 160        161       78      990         25725            1    credit_card
# 490        491       78      936         51450            2          debit
# 493        494       78      983         51450            2           cash
# 511        512       78      967         51450            2           cash
# 617        618       78      760         51450            2           cash
# 691        692       78      878        154350            6          debit
# 1056      1057       78      800         25725            1          debit
# 1193      1194       78      944         25725            1          debit
# 1204      1205       78      970         25725            1    credit_card
# 1259      1260       78      775         77175            3    credit_card
# 1384      1385       78      867         25725            1           cash
# ...

# %%
df_final = df[(df["order_value_per_item"] < 1000) & (df["order_amount"]< 500000)]

# %%
df_final
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0            1       53      746           224            2           cash
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4995      4996       73      993           330            2          debit
# 4996      4997       48      789           234            2           cash
# 4997      4998       56      867           351            3           cash
# 4998      4999       60      825           354            2    credit_card
# 4999      5000       44      734           288            2          debit
#
#                   created_at  order_value_per_item
# ...

# %%
np.mean(df_final["order_amount"])
# Out:
# 302.58051448247926

# %%
np.mean(df_final["order_value_per_item"])
# Out:
# 151.7885355479036
